# %%
import tensorflow as tf
from tensorflow.keras import layers, models

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
#import torchvision.models as models

import wandb
from wandb.integration.keras import WandbCallback

# %% [markdown]
# # 01 Task

# %% [markdown]
# # With tensorflow

# %%
# load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

print("Train:", x_train.shape)
print("Test:", x_test.shape)
# Out:
# Train: (50000, 32, 32, 3)
# Test: (10000, 32, 32, 3)

# %%
wandb.init(
    project="cnn-image-classification",
    config={
        "epochs": 150,
        "batch_size": 32,
        "learning_rate": 0.0001,
        "architecture": "CNN",
        "activation": "tanh"
    }
)

config = wandb.config
# Out:
# Finishing previous runs because reinit is set to 'default'.
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
#  View run <strong style="color:#cdcd00">jumping-leaf-11</strong> at: <a href='https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification/runs/ri0ect1l' target="_blank">https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification/runs/ri0ect1l</a><br> View project at: <a href='https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification' target="_blank">https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260330_104018-ri0ect1l/logs</code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz</code>
# Syncing run <strong><a href='https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification/runs/sf5uovwz' target="_blank">chocolate-monkey-12</a></strong> to <a href='https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification' target="_blank">https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification</a>
#  View run at <a href='https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification/runs/sf5uovwz' target="_blank">https://wandb.ai/mbu-lule-university-of-technology/cnn-image-classification/runs/sf5uovwz</a>

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# ### first version

# %%
model = models.Sequential([

    layers.Conv2D(32, (3,3), input_shape=(32,32,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64),
    layers.LeakyReLU(),

    layers.Dense(10)  # 10 classes
])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.

# %%
model.fit(
    x_train, y_train,
    epochs=config.epochs,
    batch_size=config.batch_size,
    validation_data=(x_test, y_test),
    callbacks=[WandbCallback()]
)
# Out:
# Epoch 1/150
#   19/1563 [..............................] - ETA: 8s - loss: 2.3026 - accuracy: 0.1168
# 2026-03-30 10:41:03.107292: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node SGD/AssignVariableOp.
# 1563/1563 [==============================] - ETA: 0s - loss: 2.3026 - accuracy: 0.1025
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3026 - accuracy: 0.1025 - val_loss: 2.3025 - val_accuracy: 0.0996
# Epoch 2/150
# 1560/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1019INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1019 - val_loss: 2.3025 - val_accuracy: 0.0977
# Epoch 3/150
# 1551/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.0989
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.0989 - val_loss: 2.3025 - val_accuracy: 0.0982
# Epoch 4/150
# 1557/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1032
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1031 - val_loss: 2.3025 - val_accuracy: 0.1001
# Epoch 5/150
# 1553/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.0998
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.0999 - val_loss: 2.3025 - val_accuracy: 0.1000
# Epoch 6/150
# 1555/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1039INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1039 - val_loss: 2.3025 - val_accuracy: 0.1008
# Epoch 7/150
# 1555/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1036
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1036 - val_loss: 2.3025 - val_accuracy: 0.1002
# Epoch 8/150
# 1551/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1013
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1013 - val_loss: 2.3025 - val_accuracy: 0.1008
# Epoch 9/150
# 1559/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1069
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1069 - val_loss: 2.3025 - val_accuracy: 0.1007
# Epoch 10/150
# 1556/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1030
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1030 - val_loss: 2.3025 - val_accuracy: 0.1020
# Epoch 11/150
# 1563/1563 [==============================] - ETA: 0s - loss: 2.3025 - accuracy: 0.1109
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 9s 5ms/step - loss: 2.3025 - accuracy: 0.1109 - val_loss: 2.3025 - val_accuracy: 0.0991
# Epoch 12/150
# 1560/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1011
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1010 - val_loss: 2.3025 - val_accuracy: 0.1009
# Epoch 13/150
# 1559/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1054INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1055 - val_loss: 2.3025 - val_accuracy: 0.0986
# Epoch 14/150
# 1560/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1112
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1112 - val_loss: 2.3025 - val_accuracy: 0.0993
# Epoch 15/150
# 1557/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1047INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1046 - val_loss: 2.3025 - val_accuracy: 0.0959
# Epoch 16/150
# 1562/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1021
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1021 - val_loss: 2.3025 - val_accuracy: 0.1041
# Epoch 17/150
# 1563/1563 [==============================] - ETA: 0s - loss: 2.3025 - accuracy: 0.1003INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1003 - val_loss: 2.3025 - val_accuracy: 0.1188
# Epoch 18/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1265 - val_loss: 2.3025 - val_accuracy: 0.0989
# Epoch 19/150
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1018
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1017 - val_loss: 2.3025 - val_accuracy: 0.0995
# Epoch 20/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1014 - val_loss: 2.3025 - val_accuracy: 0.1017
# Epoch 21/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1118 - val_loss: 2.3025 - val_accuracy: 0.1015
# Epoch 22/150
# 1557/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1048INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1047 - val_loss: 2.3025 - val_accuracy: 0.1028
# Epoch 23/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1072 - val_loss: 2.3025 - val_accuracy: 0.1079
# Epoch 24/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1032 - val_loss: 2.3025 - val_accuracy: 0.1213
# Epoch 25/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1143 - val_loss: 2.3025 - val_accuracy: 0.1074
# Epoch 26/150
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.3025 - accuracy: 0.1288 - val_loss: 2.3025 - val_accuracy: 0.0974
# Epoch 27/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1034 - val_loss: 2.3025 - val_accuracy: 0.1089
# Epoch 28/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1022 - val_loss: 2.3025 - val_accuracy: 0.1096
# Epoch 29/150
# 1557/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1056
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1056 - val_loss: 2.3025 - val_accuracy: 0.1096
# Epoch 30/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1199 - val_loss: 2.3025 - val_accuracy: 0.1058
# Epoch 31/150
# 1556/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1191
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1191 - val_loss: 2.3025 - val_accuracy: 0.1042
# Epoch 32/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1016 - val_loss: 2.3025 - val_accuracy: 0.1202
# Epoch 33/150
# 1555/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1331
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1330 - val_loss: 2.3025 - val_accuracy: 0.1104
# Epoch 34/150
# 1559/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1024INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1025 - val_loss: 2.3025 - val_accuracy: 0.1220
# Epoch 35/150
# 1552/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1442INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1439 - val_loss: 2.3025 - val_accuracy: 0.1039
# Epoch 36/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1304 - val_loss: 2.3025 - val_accuracy: 0.0998
# Epoch 37/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1052 - val_loss: 2.3025 - val_accuracy: 0.1088
# Epoch 38/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1121 - val_loss: 2.3025 - val_accuracy: 0.1173
# Epoch 39/150
# 1557/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1171INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1171 - val_loss: 2.3025 - val_accuracy: 0.1127
# Epoch 40/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1031 - val_loss: 2.3025 - val_accuracy: 0.1464
# Epoch 41/150
# 1551/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1292INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1292 - val_loss: 2.3025 - val_accuracy: 0.1342
# Epoch 42/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1335 - val_loss: 2.3025 - val_accuracy: 0.1194
# Epoch 43/150
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.3025 - accuracy: 0.1289 - val_loss: 2.3025 - val_accuracy: 0.1073
# Epoch 44/150
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.3025 - accuracy: 0.1284 - val_loss: 2.3025 - val_accuracy: 0.1129
# Epoch 45/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1321 - val_loss: 2.3025 - val_accuracy: 0.1112
# Epoch 46/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1311 - val_loss: 2.3025 - val_accuracy: 0.1095
# Epoch 47/150
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1219
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1218 - val_loss: 2.3025 - val_accuracy: 0.1178
# Epoch 48/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1265 - val_loss: 2.3025 - val_accuracy: 0.1151
# Epoch 49/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1148 - val_loss: 2.3025 - val_accuracy: 0.1428
# Epoch 50/150
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1220
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1219 - val_loss: 2.3025 - val_accuracy: 0.1366
# Epoch 51/150
# 1551/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1406
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1404 - val_loss: 2.3025 - val_accuracy: 0.1396
# Epoch 52/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1447 - val_loss: 2.3025 - val_accuracy: 0.1311
# Epoch 53/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1299 - val_loss: 2.3025 - val_accuracy: 0.1295
# Epoch 54/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1245 - val_loss: 2.3025 - val_accuracy: 0.1373
# Epoch 55/150
# 1552/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1221
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1227 - val_loss: 2.3025 - val_accuracy: 0.1466
# Epoch 56/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1360 - val_loss: 2.3025 - val_accuracy: 0.1407
# Epoch 57/150
# 1559/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1352INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1352 - val_loss: 2.3025 - val_accuracy: 0.1301
# Epoch 58/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1092 - val_loss: 2.3025 - val_accuracy: 0.1296
# Epoch 59/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1446 - val_loss: 2.3025 - val_accuracy: 0.1178
# Epoch 60/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1200 - val_loss: 2.3025 - val_accuracy: 0.1354
# Epoch 61/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1362 - val_loss: 2.3025 - val_accuracy: 0.1357
# Epoch 62/150
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1318
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1319 - val_loss: 2.3025 - val_accuracy: 0.1438
# Epoch 63/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1124 - val_loss: 2.3025 - val_accuracy: 0.1422
# Epoch 64/150
# 1555/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1440
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1438 - val_loss: 2.3025 - val_accuracy: 0.1205
# Epoch 65/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1323 - val_loss: 2.3025 - val_accuracy: 0.1318
# Epoch 66/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1171 - val_loss: 2.3025 - val_accuracy: 0.1550
# Epoch 67/150
# 1554/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1423INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1423 - val_loss: 2.3025 - val_accuracy: 0.1404
# Epoch 68/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1261 - val_loss: 2.3025 - val_accuracy: 0.1535
# Epoch 69/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1255 - val_loss: 2.3025 - val_accuracy: 0.1561
# Epoch 70/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1297 - val_loss: 2.3025 - val_accuracy: 0.1414
# Epoch 71/150
# 1555/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1241
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1243 - val_loss: 2.3025 - val_accuracy: 0.1599
# Epoch 72/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1395 - val_loss: 2.3025 - val_accuracy: 0.1459
# Epoch 73/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1313 - val_loss: 2.3025 - val_accuracy: 0.1457
# Epoch 74/150
# 1560/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1498
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.3025 - accuracy: 0.1497 - val_loss: 2.3025 - val_accuracy: 0.1448
# Epoch 75/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1441 - val_loss: 2.3025 - val_accuracy: 0.1308
# Epoch 76/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1341 - val_loss: 2.3025 - val_accuracy: 0.1336
# Epoch 77/150
# 1559/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1389
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1388 - val_loss: 2.3025 - val_accuracy: 0.1234
# Epoch 78/150
# 1556/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1069INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.3025 - accuracy: 0.1071 - val_loss: 2.3025 - val_accuracy: 0.1521
# Epoch 79/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1291 - val_loss: 2.3025 - val_accuracy: 0.1481
# Epoch 80/150
# 1560/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1327
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1327 - val_loss: 2.3025 - val_accuracy: 0.1524
# Epoch 81/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1329 - val_loss: 2.3025 - val_accuracy: 0.1429
# Epoch 82/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1419 - val_loss: 2.3025 - val_accuracy: 0.1548
# Epoch 83/150
# 1558/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1349
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# ...
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1387 - val_loss: 2.3025 - val_accuracy: 0.1613
# Epoch 114/150
# 1555/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1379INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1378 - val_loss: 2.3025 - val_accuracy: 0.1575
# Epoch 115/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1485 - val_loss: 2.3025 - val_accuracy: 0.1606
# Epoch 116/150
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.3025 - accuracy: 0.1416 - val_loss: 2.3025 - val_accuracy: 0.1646
# Epoch 117/150
# 1553/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1344
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1348 - val_loss: 2.3025 - val_accuracy: 0.1593
# Epoch 118/150
# 1561/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1492INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 10s 6ms/step - loss: 2.3025 - accuracy: 0.1493 - val_loss: 2.3025 - val_accuracy: 0.1565
# Epoch 119/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1498 - val_loss: 2.3025 - val_accuracy: 0.1553
# Epoch 120/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1405 - val_loss: 2.3025 - val_accuracy: 0.1565
# Epoch 121/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1434 - val_loss: 2.3025 - val_accuracy: 0.1542
# Epoch 122/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1225 - val_loss: 2.3025 - val_accuracy: 0.1723
# Epoch 123/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1457 - val_loss: 2.3025 - val_accuracy: 0.1468
# Epoch 124/150
# 1560/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1464
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1464 - val_loss: 2.3025 - val_accuracy: 0.1594
# Epoch 125/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1454 - val_loss: 2.3025 - val_accuracy: 0.1590
# Epoch 126/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1457 - val_loss: 2.3025 - val_accuracy: 0.1569
# Epoch 127/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1275 - val_loss: 2.3025 - val_accuracy: 0.1691
# Epoch 128/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1550 - val_loss: 2.3025 - val_accuracy: 0.1661
# Epoch 129/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1516 - val_loss: 2.3025 - val_accuracy: 0.1436
# Epoch 130/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1316 - val_loss: 2.3025 - val_accuracy: 0.1661
# Epoch 131/150
# 1563/1563 [==============================] - ETA: 0s - loss: 2.3025 - accuracy: 0.1521
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1521 - val_loss: 2.3025 - val_accuracy: 0.1517
# Epoch 132/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1430 - val_loss: 2.3025 - val_accuracy: 0.1596
# Epoch 133/150
# 1557/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1429
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1429 - val_loss: 2.3025 - val_accuracy: 0.1573
# Epoch 134/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1411 - val_loss: 2.3025 - val_accuracy: 0.1703
# Epoch 135/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1475 - val_loss: 2.3025 - val_accuracy: 0.1578
# Epoch 136/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1500 - val_loss: 2.3025 - val_accuracy: 0.1644
# Epoch 137/150
# 1551/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1490
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.3025 - accuracy: 0.1491 - val_loss: 2.3025 - val_accuracy: 0.1627
# Epoch 138/150
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1446 - val_loss: 2.3025 - val_accuracy: 0.1728
# Epoch 139/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1406 - val_loss: 2.3025 - val_accuracy: 0.1653
# Epoch 140/150
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.3025 - accuracy: 0.1522 - val_loss: 2.3025 - val_accuracy: 0.1643
# Epoch 141/150
# 1551/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1334
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 8s 5ms/step - loss: 2.3025 - accuracy: 0.1336 - val_loss: 2.3025 - val_accuracy: 0.1654
# Epoch 142/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1366 - val_loss: 2.3025 - val_accuracy: 0.1723
# Epoch 143/150
# 1557/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1475
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 12s 8ms/step - loss: 2.3025 - accuracy: 0.1476 - val_loss: 2.3025 - val_accuracy: 0.1660
# Epoch 144/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1468 - val_loss: 2.3025 - val_accuracy: 0.1682
# Epoch 145/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1423 - val_loss: 2.3025 - val_accuracy: 0.1624
# Epoch 146/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1303 - val_loss: 2.3025 - val_accuracy: 0.1760
# Epoch 147/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1456 - val_loss: 2.3025 - val_accuracy: 0.1770
# Epoch 148/150
# 1563/1563 [==============================] - 11s 7ms/step - loss: 2.3025 - accuracy: 0.1510 - val_loss: 2.3025 - val_accuracy: 0.1776
# Epoch 149/150
# 1559/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1605
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 16s 11ms/step - loss: 2.3025 - accuracy: 0.1604 - val_loss: 2.3025 - val_accuracy: 0.1650
# Epoch 150/150
# 1558/1563 [============================>.] - ETA: 0s - loss: 2.3025 - accuracy: 0.1429
# /Users/mariebu/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# INFO:tensorflow:Assets written to: /Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best/assets
# wandb: Adding directory to artifact (/Users/mariebu/Documents/GitHub/Advanced-deep-learning/Lab0/wandb/run-20260330_104050-sf5uovwz/files/model-best)... Done. 0.0s
# 1563/1563 [==============================] - 12s 7ms/step - loss: 2.3025 - accuracy: 0.1430 - val_loss: 2.3025 - val_accuracy: 0.1649

# %%
#results
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Accuracy sur test set :", test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.6191 - accuracy: 0.4338
# Accuracy sur test set : 0.43380001187324524

# %% [markdown]
# ### second version - with adam

# %%
model = models.Sequential([

    layers.Conv2D(32, (3,3), input_shape=(32,32,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64),
    layers.LeakyReLU(),

    layers.Dense(10)  # 10 classes
])

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
model.fit(
    x_train, y_train,
    epochs=50,
    validation_data=(x_test, y_test)
)

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Accuracy sur test set :", test_acc)

# %% [markdown]
# ### third version - with tanh

# %%
# Model
model = models.Sequential([

    layers.Conv2D(32, (3,3), input_shape=(32,32,3)),
    layers.Activation('tanh'),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3)),
    layers.Activation('tanh'),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64),
    layers.Activation('tanh'),

    layers.Dense(10)
])

# Optimizer Adam
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Entraînement
model.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/15
# 2026-03-30 11:03:28.743851: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
#  724/1563 [============>.................] - ETA: 5s - loss: 1.9824 - accuracy: 0.2851
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 27
#      20 model.compile(
#      21     optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#      22     loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#      23     metrics=['accuracy']
#      24 )
#      26 # Entraînement
# ---> 27 model.fit(x_train, y_train, epochs=15, validation_data=(x_test, y_test))
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)   1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)   1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/miniforge3/envs/lidar_env_arm/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Results

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Accuracy sur test set :", test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.8535 - accuracy: 0.3498
# Accuracy sur test set : 0.3497999906539917
